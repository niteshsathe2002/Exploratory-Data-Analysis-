# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\DATA\1sem_marks.csv')

# %%
df.head()
# Out:
#    SR.NO  ROLL_NO  ST_101  ST_102  ST_103  ST_104  ST_105  ST_106  Total  \
# 0      1   368186      59      53      42      34      59      25    272
# 1      2   368187      63      78      51      55      68      62    377
# 2      3   368188      70      72      56      78      72      67    415
# 3      4   368189      17      16      20      15       4      22     94
# 4      5   368190      46      42      34      34      53      63    272
#
#    Percentage Grade
# 0   45.333333     C
# 1   62.833333     A
# 2   69.166667     A
# 3   15.666667     D
# 4   45.333333     B

# %%
df.drop(["SR.NO","ROLL_NO"],axis=1).describe()
# Out:
#           ST_101     ST_102     ST_103     ST_104     ST_105     ST_106  \
# count  43.000000  43.000000  43.000000  43.000000  43.000000  43.000000
# mean   49.581395  45.162791  46.906977  40.790698  55.000000  55.558140
# std    17.931394  21.836983  16.496484  20.444534  19.093754  16.660907
# min    16.000000   3.000000  10.000000   6.000000   4.000000  22.000000
# 25%    38.500000  35.000000  34.000000  23.500000  43.500000  47.000000
# 50%    53.000000  45.000000  50.000000  40.000000  58.000000  58.000000
# 75%    64.000000  61.500000  58.000000  55.000000  69.500000  66.500000
# max    79.000000  89.000000  84.000000  78.000000  85.000000  84.000000
#
#             Total  Percentage
# count   43.000000   43.000000
# mean   293.000000   48.833333
# std    101.886959   16.981160
# min     94.000000   15.666667
# 25%    227.000000   37.833333
# 50%    291.000000   48.500000
# 75%    366.000000   61.000000
# max    490.000000   81.666667

# %%
plt.hist(df.Percentage,color="maroon",edgecolor="k",bins=10)
plt.show()

# %%
plt.boxplot(df.Total,OverflowError)
plt.show()

# %%
plt.bar(df.index,df.Grade)
# Out:
# <BarContainer object of 43 artists>

# %%
df1=pd.DataFrame((df.Grade).value_counts())
plt.pie(df1.Grade,labels=df1.index)
plt.show()

# %%
sns.heatmap(df.drop(["ROLL_NO","SR.NO","Grade"],axis=1))
# Out:
# <Axes: >

# %%
sns.pairplot(df.drop(["ROLL_NO","SR.NO","Grade"],axis=1))
